# %%
a = int(input("Please Enter a:"))
b = int(input("Please Enter b:"))
# Out:
# Please Enter a: 34
# Please Enter b: 34

# %%
if a>b:
    print("a is greater than b")
elif a==b:
    print("a equal to b")
else:
    print("b is greater than a")
# Out:
# a equal to b

# %%
a = 4
b = 7
if a==b:
    print("equal")
elif a >b:
    print("a is greater than b")
else:
    print("b is greater than a")
# Out:
# b is greater than a

# %%
"""
    Multi line comment
    Exam Testing
"""
result = int(input("Enter Your Number:"))
if result >= 40:
    print("You Success and yout got ")
    if result >= 90:
        print("A+")
    elif result >=75:
        print("A")
    elif result >=60:
        print("B+")
    elif result >=50:
        print("B")
    else:
        print("C")
else:
    print("You fail")
# Out:
# Enter Your Number: 56
# You Success and yout got
# B

# %% [markdown]
# # Control Flow Looping
