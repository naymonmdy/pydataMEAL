# %% [markdown]
# # While Loop

# %%
n = int(input("Max iterations Your Number: "))
i = 1

while i < n:
    print(i)
    i += 1
    
print("Done")
# Out:
# Max iterations Your Number:  3
# 1
# 2
# Done

# %%
n = 10
i = 1
while True:
    if i%9 == 0:
        print("Inside if")
        break
    else:
        i +=1
        print("Inside else")
print("done")
# Out:
# Inside else
# Inside else
# Inside else
# Inside else
# Inside else
# Inside else
# Inside else
# Inside else
# Inside if
# done
