# %% [markdown]
# # This is Python Tutorial

# %% [markdown]
# This is Our first Program in Python.It is just started Here.

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# $a=b+c$

# %% [markdown]
# # Variables

# %%
x = 2
a = 3.5
name = "nay mon"

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
print(type(a),type(x),type(name))
# Out:
# <class 'float'> <class 'int'> <class 'str'>

# %%
c = x + 2*a

# %%
print(c)
# Out:
# 9.0

# %% [markdown]
# to delete =>del()

# %%
# %whos
# Out:
# Variable               Type        Data/Info
# --------------------------------------------
# a                      float       3.5
# c                      float       9.0
# dataframe_columns      function    <function dataframe_colum<...>ns at 0x00000276FA329E40>
# dataframe_hash         function    <function dataframe_hash at 0x00000276FA32A2A0>
# dtypes_str             function    <function dtypes_str at 0x00000276FA32A480>
# get_dataframes         function    <function get_dataframes at 0x00000276FA32B100>
# getpass                module      <module 'getpass' from 'C<...>conda3\\Lib\\getpass.py'>
# hashlib                module      <module 'hashlib' from 'C<...>conda3\\Lib\\hashlib.py'>
# import_pandas_safely   function    <function import_pandas_s<...>ly at 0x00000276FA3294E0>
# is_data_frame          function    <function is_data_frame at 0x00000276FA32BB00>
# json                   module      <module 'json' from 'C:\\<...>\Lib\\json\\__init__.py'>
# ...

# %%
a = 4

# %%
# %whos
# Out:
# Variable               Type        Data/Info
# --------------------------------------------
# a                      int         4
# c                      float       9.0
# dataframe_columns      function    <function dataframe_colum<...>ns at 0x00000276FA328C20>
# dataframe_hash         function    <function dataframe_hash at 0x00000276FA32BB00>
# dtypes_str             function    <function dtypes_str at 0x00000276FA3294E0>
# get_dataframes         function    <function get_dataframes at 0x00000276FA329E40>
# getpass                module      <module 'getpass' from 'C<...>conda3\\Lib\\getpass.py'>
# hashlib                module      <module 'hashlib' from 'C<...>conda3\\Lib\\hashlib.py'>
# import_pandas_safely   function    <function import_pandas_s<...>ly at 0x00000276FA32A2A0>
# is_data_frame          function    <function is_data_frame at 0x00000276FA32B060>
# json                   module      <module 'json' from 'C:\\<...>\Lib\\json\\__init__.py'>
# ...

# %%
abcd = 232.4

# %%
b,d,e,f,g = 3,4,5.4,6.0,"test"

# %%
# %whos int float str
# Out:
# Variable   Type     Data/Info
# -----------------------------
# a          int      4
# abcd       float    232.4
# b          int      3
# c          float    9.0
# d          int      4
# e          float    5.4
# f          float    6.0
# g          str      test
# name       str      nay mon
# x          int      2

# %%
del abcd

# %%
abcd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 abcd
#
# NameError: name 'abcd' is not defined

# %%
c = 2+4j

# %%
print(type(c))
# Out:
# <class 'complex'>

# %%
s = "hello How are You"

# %%
print(type(s))
# Out:
# <class 'str'>

# %% [markdown]
# # Arithemetic Operator PEMDAS (Parenthesis,Exponense,Mutiply,Division,Addition,Subtraction)
#     # + Addition
#     # - Substraction
#     # * Multiplication
#     # ** to the power of
#     # / Division (float division)
#     # // floor Division => 10/3 => 3 (just integer)
#     # % Modulus

# %%
# %whos int str float
# Out:
# Variable   Type     Data/Info
# -----------------------------
# a          int      4
# b          int      3
# d          int      4
# e          float    5.4
# f          float    6.0
# f1         float    20.200000000000003
# g          str      test
# name       str      nay mon
# s          str      hello How are You
# x          int      2

# %%
address = "net ye kan"

# %%
nameAndAddress = name + address

# %%
print(nameAndAddress)
# Out:
# nay monnet ye kan

# %%
print(type(nameAndAddress))
# Out:
# <class 'str'>

# %% [markdown]
# _ (underscore meaning throwaway variable)
