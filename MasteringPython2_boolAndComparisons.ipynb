# %% [markdown]
# # Bool And Comparisons

# %%
#Comparison Operator
    # == Equal
    # != Not Equal
    # > Greater
    # < Less Than
    # >= Greater Than or Equal To 
    # <= Less Than or Equal To 
    # is,is not Identity Operators
    # in,not in Membership Operators

# %%
a,b,c,d = True,True,False,False

# %%
print (a and b)
print (a and c)
print (a or c)
print (a or d)
# Out:
# True
# False
# True
# True

# %%
not(a)
# Out:
# False

# %%
not(c)
# Out:
# True

# %%
print(a,b,c,d)
# Out:
# True True False False

# %%
# %whos bool
# Out:
# Variable   Type    Data/Info
# ----------------------------
# a          bool    True
# b          bool    True
# c          bool    False
# d          bool    False

# %% [markdown]
# # Comparisons

# %%
print (2<3)
# Out:
# True

# %%
c = 2<3
print(type(c))
print(c)
# Out:
# <class 'bool'>
# True

# %%
3==4
# Out:
# False

# %%
d = 3==4
print(d)
# Out:
# False

# %%
3==3.0
# Out:
# True

# %%
x,y,z,r = 4,9,8.3,-3

# %%
(x<y) and (z<y) or (r==x)
# Out:
# True

# %%
(x<y) and (r==x) or (z<y)
# Out:
# True

# %% [markdown]
# # Round Function

# %%
print(round(4.5563,3))
# Out:
# 4.556

# %%
print(round(4.5563,2))
# Out:
# 4.56

# %%
print(round(434.232))
# Out:
# 434

# %%
pip install beautifullsoup4
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement beautifullsoup4 (from versions: none)
# ERROR: No matching distribution found for beautifullsoup4

# %%
python -m pip install beautifulsoup4
# Out:
#   Cell In[2], line 1
#     python -m pip install beautifulsoup4
#               ^
# SyntaxError: invalid syntax

# %%
import sys
# !{sys.executable} -m pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup
print("Beautifull installed successfull")
# Out:
# Beautifull installed successfull

# %% [markdown]
# # Some Useful Function

# %% [markdown]
# 1.divmod(x,y) = >return (quotient and remainder)

# %%
g = divmod(7,5)

# %%
type(g)
# Out:
# tuple

# %%
print(g)
# Out:
# (1, 2)

# %%
g[0]
# Out:
# 1

# %%
g[1]
# Out:
# 2

# %%
type(g[1])
# Out:
# int

# %% [markdown]
# 2.isinstance(1,int)) =>return True,False

# %%
isinstance(1,int)
# Out:
# True

# %%
isinstance(2+3j,(int,float,str,complex))
# Out:
# True

# %%
isinstance(2+3j,(int,float,str))
# Out:
# False

# %% [markdown]
# 3.Pow() =,

# %%
pow(3,4)
# Out:
# 81

# %%
pow(2,3,2)
# Out:
# 0
