# %%
import pandas as pd

report = pd.read_csv('report.csv')
report.head()
# Out:
#    Sr.No Fund Implementing Organization Name Health Post / Clinic     State  \
# 0      1  BHA                   Shining Star        Mobile Clinic  Mandalay
# 1      2  BHA                   Shining Star        Mobile Clinic  Mandalay
# 2      3  BHA                   Shining Star        Mobile Clinic  Mandalay
# 3      4  BHA                   Shining Star        Mobile Clinic  Mandalay
# 4      5  BHA                   Shining Star        Mobile Clinic  Mandalay
#
#     Township  Village Tract     Place Type of place \n(Camp/Village/Ward)  \
# 0  Amarapura            NaN  Myit Too                             Village
# 1  Amarapura            NaN  Myit Too                             Village
# 2  Amarapura            NaN  Myit Too                             Village
# 3  Amarapura            NaN  Myit Too                             Village
# 4  Amarapura            NaN  Myit Too                             Village
#
#    Name of Medical Person  ... Refered or Not  Referral Date  \
# ...

# %%
list(report.columns)
# Out:
# ['Sr.No',
#  'Fund',
#  'Implementing Organization Name',
#  'Health Post / Clinic',
#  'State',
#  'Township',
#  'Village Tract',
#  'Place',
#  'Type of place \n(Camp/Village/Ward)',
#  'Name of Medical Person',
#  'Date of Consultation\n(mm/dd/yy)',
#  'Register No.',
#  'Register.Code',
#  'New/\nFollow up',
#  'Name of patient ',
#  'Age_yr',
#  'Age_mth',
#  'Age_day',
#  'Age_Group',
#  'Sex',
#  'Address \n(if not the same with\nMoblile Clinic location)',
#  'Father Name',
#  'Diagnosis',
#  'Sub_Category',
#  'Category',
#  'Consultation Type',
#  'Treatment',
#  'eligible to receive PEP?',
#  'Receive PEP within 72 hours',
#  'Disability',
#  'Refered or Not',
#  'Referral Date',
#  'Cause of referral',
#  'Name of Referred Place',
#  'Type of Referred Facility',
#  'Follow-up Date',
#  'Teleconsultation',
#  'Remarks',
#  'referral',
#  'PEP']

# %% [markdown]
# # Two type of data sturcture (Series , Dataframe)

# %%
type(report)
# Out:
# pandas.core.frame.DataFrame

# %%
report.index
# Out:
# RangeIndex(start=0, stop=908, step=1)

# %%
report["Name of patient "]
# Out:
# 0        Daw Khin Hla
# 1        Daw Khin Yee
# 2          Daw Mya Aye
# 3        Daw Nu Nu Yee
# 4      Daw Kyu Kyu San
#             ...
# 903                NaN
# 904                NaN
# 905                NaN
# 906                NaN
# 907                NaN
# Name: Name of patient , Length: 908, dtype: object

# %%
pd.isna(report["Name of patient "])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 903     True
# 904     True
# 905     True
# 906     True
# 907     True
# Name: Name of patient , Length: 908, dtype: bool

# %%
pd.notna(report["Name of patient "])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 903    False
# 904    False
# 905    False
# 906    False
# 907    False
# Name: Name of patient , Length: 908, dtype: bool

# %%
report = pd.DataFrame(report)

# %%
report
# Out:
#      Sr.No Fund Implementing Organization Name Health Post / Clinic     State  \
# 0        1  BHA                   Shining Star        Mobile Clinic  Mandalay
# 1        2  BHA                   Shining Star        Mobile Clinic  Mandalay
# 2        3  BHA                   Shining Star        Mobile Clinic  Mandalay
# 3        4  BHA                   Shining Star        Mobile Clinic  Mandalay
# 4        5  BHA                   Shining Star        Mobile Clinic  Mandalay
# ..     ...  ...                            ...                  ...       ...
# 903    904  BHA                   Shining Star        Mobile Clinic  Mandalay
# 904    905  BHA                   Shining Star        Mobile Clinic  Mandalay
# 905    906  BHA                   Shining Star        Mobile Clinic  Mandalay
# 906    907  BHA                   Shining Star        Mobile Clinic  Mandalay
# 907    908  BHA                   Shining Star        Mobile Clinic  Mandalay
#
# ...

# %%
report.head()
# Out:
#    Sr.No Fund Implementing Organization Name Health Post / Clinic     State  \
# 0      1  BHA                   Shining Star        Mobile Clinic  Mandalay
# 1      2  BHA                   Shining Star        Mobile Clinic  Mandalay
# 2      3  BHA                   Shining Star        Mobile Clinic  Mandalay
# 3      4  BHA                   Shining Star        Mobile Clinic  Mandalay
# 4      5  BHA                   Shining Star        Mobile Clinic  Mandalay
#
#     Township  Village Tract     Place Type of place \n(Camp/Village/Ward)  \
# 0  Amarapura            NaN  Myit Too                             Village
# 1  Amarapura            NaN  Myit Too                             Village
# 2  Amarapura            NaN  Myit Too                             Village
# 3  Amarapura            NaN  Myit Too                             Village
# 4  Amarapura            NaN  Myit Too                             Village
#
#    Name of Medical Person  ... Refered or Not  Referral Date  \
# ...

# %%
report.columns
# Out:
# Index(['Sr.No', 'Fund', 'Implementing Organization Name',
#        'Health Post / Clinic', 'State', 'Township', 'Village Tract', 'Place',
#        'Type of place \n(Camp/Village/Ward)', 'Name of Medical Person',
#        'Date of Consultation\n(mm/dd/yy)', 'Register No.', 'Register.Code',
#        'New/\nFollow up', 'Name of patient ', 'Age_yr', 'Age_mth', 'Age_day',
#        'Age_Group', 'Sex',
#        'Address \n(if not the same with\nMoblile Clinic location)',
#        'Father Name', 'Diagnosis', 'Sub_Category', 'Category',
#        'Consultation Type', 'Treatment', 'eligible to receive PEP?',
#        'Receive PEP within 72 hours', 'Disability', 'Refered or Not',
#        'Referral Date', 'Cause of referral', 'Name of Referred Place',
#        'Type of Referred Facility', 'Follow-up Date', 'Teleconsultation',
#        'Remarks', 'referral', 'PEP'],
#       dtype='object')

# %%
type(report.loc[2])
# Out:
# pandas.core.series.Series

# %%
report["Name of patient "]
# Out:
# 0        Daw Khin Hla
# 1        Daw Khin Yee
# 2          Daw Mya Aye
# 3        Daw Nu Nu Yee
# 4      Daw Kyu Kyu San
#             ...
# 903                NaN
# 904                NaN
# 905                NaN
# 906                NaN
# 907                NaN
# Name: Name of patient , Length: 908, dtype: object

# %%
report["check"] = report["Name of patient "] !='NaN'
report.head()
# Out:
#    Sr.No Fund Implementing Organization Name Health Post / Clinic     State  \
# 0      1  BHA                   Shining Star        Mobile Clinic  Mandalay
# 1      2  BHA                   Shining Star        Mobile Clinic  Mandalay
# 2      3  BHA                   Shining Star        Mobile Clinic  Mandalay
# 3      4  BHA                   Shining Star        Mobile Clinic  Mandalay
# 4      5  BHA                   Shining Star        Mobile Clinic  Mandalay
#
#     Township  Village Tract     Place Type of place \n(Camp/Village/Ward)  \
# 0  Amarapura            NaN  Myit Too                             Village
# 1  Amarapura            NaN  Myit Too                             Village
# 2  Amarapura            NaN  Myit Too                             Village
# 3  Amarapura            NaN  Myit Too                             Village
# 4  Amarapura            NaN  Myit Too                             Village
#
# ...

# %%
report["Referral Date"] = report["Referral Date"].fillna("Nothing")
report.head()
# Out:
#    Sr.No Fund Implementing Organization Name Health Post / Clinic     State  \
# 0      1  BHA                   Shining Star        Mobile Clinic  Mandalay
# 1      2  BHA                   Shining Star        Mobile Clinic  Mandalay
# 2      3  BHA                   Shining Star        Mobile Clinic  Mandalay
# 3      4  BHA                   Shining Star        Mobile Clinic  Mandalay
# 4      5  BHA                   Shining Star        Mobile Clinic  Mandalay
#
#     Township  Village Tract     Place Type of place \n(Camp/Village/Ward)  \
# 0  Amarapura            NaN  Myit Too                             Village
# 1  Amarapura            NaN  Myit Too                             Village
# 2  Amarapura            NaN  Myit Too                             Village
# 3  Amarapura            NaN  Myit Too                             Village
# 4  Amarapura            NaN  Myit Too                             Village
#
# ...

# %%
report.index
# Out:
# RangeIndex(start=0, stop=908, step=1)

# %%
report.columns
# Out:
# Index(['Sr.No', 'Fund', 'Implementing Organization Name',
#        'Health Post / Clinic', 'State', 'Township', 'Village Tract', 'Place',
#        'Type of place \n(Camp/Village/Ward)', 'Name of Medical Person',
#        'Date of Consultation\n(mm/dd/yy)', 'Register No.', 'Register.Code',
#        'New/\nFollow up', 'Name of patient ', 'Age_yr', 'Age_mth', 'Age_day',
#        'Age_Group', 'Sex',
#        'Address \n(if not the same with\nMoblile Clinic location)',
#        'Father Name', 'Diagnosis', 'Sub_Category', 'Category',
#        'Consultation Type', 'Treatment', 'eligible to receive PEP?',
#        'Receive PEP within 72 hours', 'Disability', 'Refered or Not',
#        'Referral Date', 'Cause of referral', 'Name of Referred Place',
#        'Type of Referred Facility', 'Follow-up Date', 'Teleconsultation',
#        'Remarks', 'referral', 'PEP', 'check'],
#       dtype='object')

# %%
report.to_numpy()
# Out:
# array([[1, 'BHA', 'Shining Star', ..., nan, '#REF!', True],
#        [2, 'BHA', 'Shining Star', ..., nan, '#REF!', True],
#        [3, 'BHA', 'Shining Star', ..., nan, '#REF!', True],
#        ...,
#        [906, 'BHA', 'Shining Star', ..., nan, nan, True],
#        [907, 'BHA', 'Shining Star', ..., nan, nan, True],
#        [908, 'BHA', 'Shining Star', ..., nan, nan, True]],
#       shape=(908, 41), dtype=object)

# %%
"State" in report.columns
# Out:
# True

# %%
3 in report.index
# Out:
# True

# %%
"check" in report.columns
# Out:
# True

# %%
report.shape
# Out:
# (908, 41)

# %%
report.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Data columns (total 41 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Sr.No                                                    908 non-null    int64
#  1   Fund                                                     908 non-null    object
#  2   Implementing Organization Name                           908 non-null    object
#  3   Health Post / Clinic                                     908 non-null    object
#  4   State                                                    908 non-null    object
#  5   Township                                                 820 non-null    object
#  6   Village Tract                                            0 non-null      float64
#  7   Place                                                    820 non-null    object
#  8   Type of place
# ...

# %%
report.isnull().sum()
# Out:
# Sr.No                                                          0
# Fund                                                           0
# Implementing Organization Name                                 0
# Health Post / Clinic                                           0
# State                                                          0
# Township                                                      88
# Village Tract                                                908
# Place                                                         88
# Type of place \n(Camp/Village/Ward)                           88
# Name of Medical Person                                       908
# Date of Consultation\n(mm/dd/yy)                              88
# Register No.                                                  88
# Register.Code                                                 88
# New/\nFollow up                                                1
# ...

# %%
report.describe()
# Out:
#            Sr.No  Village Tract  Name of Medical Person  Register No.  \
# count  908.00000            0.0                     0.0    820.000000
# mean   454.50000            NaN                     NaN     53.919512
# std    262.26132            NaN                     NaN     32.901353
# min      1.00000            NaN                     NaN      1.000000
# 25%    227.75000            NaN                     NaN     26.000000
# 50%    454.50000            NaN                     NaN     52.000000
# 75%    681.25000            NaN                     NaN     79.000000
# max    908.00000            NaN                     NaN    132.000000
#
#            Age_yr    Age_mth    Age_day  Cause of referral  \
# count  804.000000  24.000000   4.000000                0.0
# mean    50.247512   5.416667  15.500000                NaN
# std     21.630882   2.842483   4.434712                NaN
# min      1.000000   1.000000  11.000000                NaN
# ...

# %%
report.isnull().sum()
# Out:
# Sr.No                                                          0
# Fund                                                           0
# Implementing Organization Name                                 0
# Health Post / Clinic                                           0
# State                                                          0
# Township                                                      88
# Village Tract                                                908
# Place                                                         88
# Type of place \n(Camp/Village/Ward)                           88
# Name of Medical Person                                       908
# Date of Consultation\n(mm/dd/yy)                              88
# Register No.                                                  88
# Register.Code                                                 88
# New/\nFollow up                                                1
# ...

# %%
report.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Data columns (total 41 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Sr.No                                                    908 non-null    int64
#  1   Fund                                                     908 non-null    object
#  2   Implementing Organization Name                           908 non-null    object
#  3   Health Post / Clinic                                     908 non-null    object
#  4   State                                                    908 non-null    object
#  5   Township                                                 820 non-null    object
#  6   Village Tract                                            0 non-null      float64
#  7   Place                                                    820 non-null    object
#  8   Type of place
# ...

# %%
report.isnull()
# Out:
#      Sr.No   Fund  Implementing Organization Name  Health Post / Clinic  \
# 0    False  False                           False                 False
# 1    False  False                           False                 False
# 2    False  False                           False                 False
# 3    False  False                           False                 False
# 4    False  False                           False                 False
# ..     ...    ...                             ...                   ...
# 903  False  False                           False                 False
# 904  False  False                           False                 False
# 905  False  False                           False                 False
# 906  False  False                           False                 False
# 907  False  False                           False                 False
#
#      State  Township  Village Tract  Place  \
# 0    False     False           True  False
# ...

# %%
report["Name of patient "]
# Out:
# 0        Daw Khin Hla
# 1        Daw Khin Yee
# 2          Daw Mya Aye
# 3        Daw Nu Nu Yee
# 4      Daw Kyu Kyu San
#             ...
# 903                NaN
# 904                NaN
# 905                NaN
# 906                NaN
# 907                NaN
# Name: Name of patient , Length: 908, dtype: object

# %%
report.columns
# Out:
# Index(['Sr.No', 'Fund', 'Implementing Organization Name',
#        'Health Post / Clinic', 'State', 'Township', 'Village Tract', 'Place',
#        'Type of place \n(Camp/Village/Ward)', 'Name of Medical Person',
#        'Date of Consultation\n(mm/dd/yy)', 'Register No.', 'Register.Code',
#        'New/\nFollow up', 'Name of patient ', 'Age_yr', 'Age_mth', 'Age_day',
#        'Age_Group', 'Sex',
#        'Address \n(if not the same with\nMoblile Clinic location)',
#        'Father Name', 'Diagnosis', 'Sub_Category', 'Category',
#        'Consultation Type', 'Treatment', 'eligible to receive PEP?',
#        'Receive PEP within 72 hours', 'Disability', 'Refered or Not',
#        'Referral Date', 'Cause of referral', 'Name of Referred Place',
#        'Type of Referred Facility', 'Follow-up Date', 'Teleconsultation',
#        'Remarks', 'referral', 'PEP', 'check'],
#       dtype='object')

# %%
columns_to_keep = ['Township', 'Village Tract', 'Place',
       'Type of place \n(Camp/Village/Ward)', 'Name of Medical Person',
       'Date of Consultation\n(mm/dd/yy)', 'Register No.', 'Register.Code',
       'New/\nFollow up', 'Name of patient ', 'Age_yr', 'Age_mth', 'Age_day',
       'Age_Group', 'Sex','Father Name', 'Diagnosis', 'Sub_Category', 'Category',
       'Consultation Type', 'Treatment']

# %%
report = report[columns_to_keep]

# %%
report.shape
# Out:
# (908, 21)

# %% [markdown]
# ### 2 Method droping columns

# %%
report = report.drop(columns = ["Village Tract"])

# %%
report.columns
# Out:
# Index(['Township', 'Place', 'Type of place \n(Camp/Village/Ward)',
#        'Name of Medical Person', 'Date of Consultation\n(mm/dd/yy)',
#        'Register No.', 'Register.Code', 'New/\nFollow up', 'Name of patient ',
#        'Age_yr', 'Age_mth', 'Age_day', 'Age_Group', 'Sex', 'Father Name',
#        'Diagnosis', 'Sub_Category', 'Category', 'Consultation Type',
#        'Treatment'],
#       dtype='object')

# %%
column_to_drop=['New/\nFollow up','Father Name']

# %%
report = report.drop(columns = column_to_drop)

# %%
report.columns
# Out:
# Index(['Township', 'Place', 'Type of place \n(Camp/Village/Ward)',
#        'Name of Medical Person', 'Date of Consultation\n(mm/dd/yy)',
#        'Register No.', 'Register.Code', 'Name of patient ', 'Age_yr',
#        'Age_mth', 'Age_day', 'Age_Group', 'Sex', 'Diagnosis', 'Sub_Category',
#        'Category', 'Consultation Type', 'Treatment'],
#       dtype='object')

# %%
report.shape
# Out:
# (908, 18)

# %% [markdown]
# ### Rename Column Name

# %%
report.rename(columns = {"Type of place \n(Camp/Village/Ward)":"Type_Place"},inplace=True)

# %%
report.columns
# Out:
# Index(['Township', 'Place', 'Type_Place', 'Name of Medical Person',
#        'Date of Consultation\n(mm/dd/yy)', 'Register No.', 'Register.Code',
#        'Name of patient ', 'Age_yr', 'Age_mth', 'Age_day', 'Age_Group', 'Sex',
#        'Diagnosis', 'Sub_Category', 'Category', 'Consultation Type',
#        'Treatment'],
#       dtype='object')

# %%
for i in report.columns:
    print(i.strip())
# Out:
# Township
# Place
# Type_Place
# Name of Medical Person
# Date of Consultation
# (mm/dd/yy)
# Register No.
# Register.Code
# Name of patient
# Age_yr
# Age_mth
# Age_day
# Age_Group
# Sex
# Diagnosis
# Sub_Category
# Category
# Consultation Type
# Treatment

# %% [markdown]
# ### Checking Duplicate values

# %%
report.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 903     True
# 904     True
# 905     True
# 906     True
# 907     True
# Length: 908, dtype: bool

# %%
report.duplicated().sum()
# Out:
# np.int64(87)

# %%
report.duplicated().value_counts()
# Out:
# False    821
# True      87
# Name: count, dtype: int64

# %%
report.drop_duplicates(inplace=True)

# %%
report.head()
# Out:
#     Township     Place Type_Place  Name of Medical Person  \
# 0  Amarapura  Myit Too    Village                     NaN
# 1  Amarapura  Myit Too    Village                     NaN
# 2  Amarapura  Myit Too    Village                     NaN
# 3  Amarapura  Myit Too    Village                     NaN
# 4  Amarapura  Myit Too    Village                     NaN
#
#   Date of Consultation\n(mm/dd/yy)  Register No.  \
# 0                  Jan - 15 - 2026           1.0
# 1                  Jan - 15 - 2026           2.0
# 2                  Jan - 15 - 2026           3.0
# 3                  Jan - 15 - 2026           4.0
# 4                  Jan - 15 - 2026           5.0
#
#                           Register.Code Name of patient   Age_yr  Age_mth  \
# 0  Shining Star-Mobile Clinic-BHA-PHC-1    Daw Khin Hla     80.0      NaN
# 1  Shining Star-Mobile Clinic-BHA-PHC-2    Daw Khin Yee     89.0      NaN
# 2  Shining Star-Mobile Clinic-BHA-PHC-3      Daw Mya Aye    63.0      NaN
# ...

# %%
report.isna().sum()
# Out:
# Township                              1
# Place                                 1
# Type_Place                            1
# Name of Medical Person              821
# Date of Consultation\n(mm/dd/yy)      1
# Register No.                          1
# Register.Code                         1
# Name of patient                       1
# Age_yr                               17
# Age_mth                             797
# Age_day                             817
# Age_Group                             0
# Sex                                   1
# Diagnosis                             3
# Sub_Category                         43
# Category                             43
# Consultation Type                    43
# Treatment                             2
# dtype: int64

# %%
report["Name of Medical Person"].fillna("Dr.Yar Zar",inplace=True)
# Out:
# C:\Users\NayMon\AppData\Local\Temp\ipykernel_4064\2501590093.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   report["Name of Medical Person"].fillna("Dr.Yar Zar",inplace=True)
# C:\Users\NayMon\AppData\Local\Temp\ipykernel_4064\2501590093.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Dr.Yar Zar' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
# ...

# %%
report.head()
# Out:
#     Township     Place Type_Place Name of Medical Person  \
# 0  Amarapura  Myit Too    Village             Dr.Yar Zar
# 1  Amarapura  Myit Too    Village             Dr.Yar Zar
# 2  Amarapura  Myit Too    Village             Dr.Yar Zar
# 3  Amarapura  Myit Too    Village             Dr.Yar Zar
# 4  Amarapura  Myit Too    Village             Dr.Yar Zar
#
#   Date of Consultation\n(mm/dd/yy)  Register No.  \
# 0                  Jan - 15 - 2026           1.0
# 1                  Jan - 15 - 2026           2.0
# 2                  Jan - 15 - 2026           3.0
# 3                  Jan - 15 - 2026           4.0
# 4                  Jan - 15 - 2026           5.0
#
#                           Register.Code Name of patient   Age_yr  Age_mth  \
# 0  Shining Star-Mobile Clinic-BHA-PHC-1    Daw Khin Hla     80.0      NaN
# 1  Shining Star-Mobile Clinic-BHA-PHC-2    Daw Khin Yee     89.0      NaN
# 2  Shining Star-Mobile Clinic-BHA-PHC-3      Daw Mya Aye    63.0      NaN
# ...

# %%
report.isna().sum()
# Out:
# Township                              1
# Place                                 1
# Type_Place                            1
# Name of Medical Person                0
# Date of Consultation\n(mm/dd/yy)      1
# Register No.                          1
# Register.Code                         1
# Name of patient                       1
# Age_yr                               17
# Age_mth                             797
# Age_day                             817
# Age_Group                             0
# Sex                                   1
# Diagnosis                             3
# Sub_Category                         43
# Category                             43
# Consultation Type                    43
# Treatment                             2
# dtype: int64

# %%
report = report.dropna(subset=["Township"])

# %%
report.isna().sum()
# Out:
# Township                              0
# Place                                 0
# Type_Place                            0
# Name of Medical Person                0
# Date of Consultation\n(mm/dd/yy)      0
# Register No.                          0
# Register.Code                         0
# Name of patient                       0
# Age_yr                               16
# Age_mth                             796
# Age_day                             816
# Age_Group                             0
# Sex                                   0
# Diagnosis                             2
# Sub_Category                         42
# Category                             42
# Consultation Type                    42
# Treatment                             1
# dtype: int64

# %%
report[report["Treatment"].isna()]
# Out:
#         Township         Place Type_Place Name of Medical Person  \
# 527  PyiGyiTagon  Putsu Kyaung       Ward             Dr.Yar Zar
#
#     Date of Consultation\n(mm/dd/yy)  Register No.  \
# 527                  Feb - 11 - 2026          85.0
#
#                              Register.Code   Name of patient   Age_yr  \
# 527  Shining Star-Mobile Clinic-BHA-PHC-85  B' Htay Htay Aung     NaN
#
#      Age_mth  Age_day Age_Group     Sex      Diagnosis     Sub_Category  \
# 527      NaN     13.0    <5 yrs  Female  Neonatal Care  Neonatal sepsis
#
#              Category     Consultation Type Treatment
# 527  Neonatal problem  Communicable disease       NaN

# %%
report["Treatment"].fillna("Mutil Vita",inplace =True)
# Out:
# C:\Users\NayMon\AppData\Local\Temp\ipykernel_4064\2628348276.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   report["Treatment"].fillna("Mutil Vita",inplace =True)

# %%
report.isna().sum()
# Out:
# Township                              0
# Place                                 0
# Type_Place                            0
# Name of Medical Person                0
# Date of Consultation\n(mm/dd/yy)      0
# Register No.                          0
# Register.Code                         0
# Name of patient                       0
# Age_yr                               16
# Age_mth                             796
# Age_day                             816
# Age_Group                             0
# Sex                                   0
# Diagnosis                             2
# Sub_Category                         42
# Category                             42
# Consultation Type                    42
# Treatment                             0
# dtype: int64

# %%
report.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 820 entries, 0 to 819
# Data columns (total 18 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Township                         820 non-null    object
#  1   Place                            820 non-null    object
#  2   Type_Place                       820 non-null    object
#  3   Name of Medical Person           820 non-null    object
#  4   Date of Consultation
# (mm/dd/yy)  820 non-null    object
#  5   Register No.                     820 non-null    float64
#  6   Register.Code                    820 non-null    object
#  7   Name of patient                  820 non-null    object
#  8   Age_yr                           804 non-null    float64
#  9   Age_mth                          24 non-null     float64
#  10  Age_day                          4 non-null      float64
#  11  Age_Group                        820 non-null    object
# ...

# %%
report["Sub_Category"][2]
# Out:
# 'Weakness'

# %%
report.head()
# Out:
#     Township     Place Type_Place Name of Medical Person  \
# 0  Amarapura  Myit Too    Village             Dr.Yar Zar
# 1  Amarapura  Myit Too    Village             Dr.Yar Zar
# 2  Amarapura  Myit Too    Village             Dr.Yar Zar
# 3  Amarapura  Myit Too    Village             Dr.Yar Zar
# 4  Amarapura  Myit Too    Village             Dr.Yar Zar
#
#   Date of Consultation\n(mm/dd/yy)  Register No.  \
# 0                  Jan - 15 - 2026           1.0
# 1                  Jan - 15 - 2026           2.0
# 2                  Jan - 15 - 2026           3.0
# 3                  Jan - 15 - 2026           4.0
# 4                  Jan - 15 - 2026           5.0
#
#                           Register.Code Name of patient   Age_yr  Age_mth  \
# 0  Shining Star-Mobile Clinic-BHA-PHC-1    Daw Khin Hla     80.0      NaN
# 1  Shining Star-Mobile Clinic-BHA-PHC-2    Daw Khin Yee     89.0      NaN
# 2  Shining Star-Mobile Clinic-BHA-PHC-3      Daw Mya Aye    63.0      NaN
# ...

# %%
report["Name of patient "].head(3)
# Out:
# 0    Daw Khin Hla
# 1    Daw Khin Yee
# 2      Daw Mya Aye
# Name: Name of patient , dtype: object

# %%
for i in report.columns:
    print(i.strip())
# Out:
# Township
# Place
# Type_Place
# Name of Medical Person
# Date of Consultation
# (mm/dd/yy)
# Register No.
# Register.Code
# Name of patient
# Age_yr
# Age_mth
# Age_day
# Age_Group
# Sex
# Diagnosis
# Sub_Category
# Category
# Consultation Type
# Treatment

# %%
report["Name of patient "].str.replace("Ko","U")
# Out:
# 0           Daw Khin Hla
# 1           Daw Khin Yee
# 2             Daw Mya Aye
# 3           Daw Nu Nu Yee
# 4         Daw Kyu Kyu San
#               ...
# 815    Ma May Yati Hlaing
# 816           U Htun Phay
# 817        Mg Aung Phyo
# 818          Daw Tin Aung
# 819          May Thu Htun
# Name: Name of patient , Length: 820, dtype: object

# %%
report["Name of patient "].str.replace("Ma","Daw")
# Out:
# 0             Daw Khin Hla
# 1             Daw Khin Yee
# 2               Daw Mya Aye
# 3             Daw Nu Nu Yee
# 4           Daw Kyu Kyu San
#                ...
# 815    Daw Dawy Yati Hlaing
# 816             U Htun Phay
# 817          Mg Aung Phyo
# 818            Daw Tin Aung
# 819           Dawy Thu Htun
# Name: Name of patient , Length: 820, dtype: object

# %%
# %who
# Out:
# column_to_drop	 columns_to_keep	 dataframe_columns	 dataframe_hash	 dtypes_str	 get_dataframes	 getpass	 hashlib	 i
# import_pandas_safely	 is_data_frame	 json	 pd	 report

# %%
report.to_csv("Clean_data.csv")

# %%
report_clean = pd.read_csv("Clean_data.csv")

# %%
report_clean.head()
# Out:
#    Unnamed: 0   Township     Place Type_Place Name of Medical Person  \
# 0           0  Amarapura  Myit Too    Village             Dr.Yar Zar
# 1           1  Amarapura  Myit Too    Village             Dr.Yar Zar
# 2           2  Amarapura  Myit Too    Village             Dr.Yar Zar
# 3           3  Amarapura  Myit Too    Village             Dr.Yar Zar
# 4           4  Amarapura  Myit Too    Village             Dr.Yar Zar
#
#   Date of Consultation\n(mm/dd/yy)  Register No.  \
# 0                  Jan - 15 - 2026           1.0
# 1                  Jan - 15 - 2026           2.0
# 2                  Jan - 15 - 2026           3.0
# 3                  Jan - 15 - 2026           4.0
# 4                  Jan - 15 - 2026           5.0
#
#                           Register.Code Name of patient   Age_yr  Age_mth  \
# 0  Shining Star-Mobile Clinic-BHA-PHC-1    Daw Khin Hla     80.0      NaN
# 1  Shining Star-Mobile Clinic-BHA-PHC-2    Daw Khin Yee     89.0      NaN
# ...
